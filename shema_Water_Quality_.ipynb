# %% [markdown]
# <a href="https://colab.research.google.com/github/nkubana0/Water-Quality-Model---Peer-Group-11/blob/main/shema_Water_Quality_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Excercise - Creating our own custom Model

# %% [markdown]
# This is a notebook that provides a quick overview of how to create your own custom model. You will be creating a simple model.
# You will be utilizing Keras and Tensorflow

# %% [markdown]
# ## Water Quality Dataset
#
# This dataset contains water quality measurements and assessments related to potability, which is the suitability of water for human consumption. The dataset's primary objective is to provide insights into water quality parameters and assist in determining whether the water is potable or not. Each row in the dataset represents a water sample with specific attributes, and the "Potability" column indicates whether the water is suitable for consumption.
#
# https://www.kaggle.com/datasets/uom190346a/water-quality-and-potability?select=water_potability.csv

# %%
#LOAD THE DATA
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l1,l2
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.optimizers import RMSprop
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy
import pandas as pd
import numpy as np

dataset = pd.read_csv('https://docs.google.com/spreadsheets/d/1H_kRGjtavba31uVjs-HILSNirokfz1R0MZa64ov4NR8/export?format=csv')

# Check for missing values
print("Missing values per column:")
print(dataset.isnull().sum())

# Impute missing values with the mean for ph, Sulfate, and Trihalomethanes
dataset['ph'].fillna(dataset['ph'].mean(), inplace=True)
dataset['Sulfate'].fillna(dataset['Sulfate'].mean(), inplace=True)
dataset['Trihalomethanes'].fillna(dataset['Trihalomethanes'].mean(), inplace=True)

# Check for missing values
print("Missing values per column:")
print(dataset.isnull().sum())
# Out:
# Missing values per column:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64
# Missing values per column:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64
# <ipython-input-2-c9d76a584deb>:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['ph'].fillna(dataset['ph'].mean(), inplace=True)
# <ipython-input-2-c9d76a584deb>:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Sulfate'].fillna(dataset['Sulfate'].mean(), inplace=True)
# <ipython-input-2-c9d76a584deb>:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Trihalomethanes'].fillna(dataset['Trihalomethanes'].mean(), inplace=True)

# %% [markdown]
# Plot the Data Appropriately

# %%
# generate 2d classification dataset
x = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

print(x)
print(y)
# Out:
#             ph    Hardness       Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890456  20791.31898     7.300212  368.516441
# 1     3.716080  129.422921  18630.05786     6.635246  333.775777
# 2     8.099124  224.236259  19909.54173     9.275884  333.775777
# 3     8.316766  214.373394  22018.41744     8.059332  356.886136
# 4     9.092223  181.101509  17978.98634     6.546600  310.135738
# ...        ...         ...          ...          ...         ...
# 3271  4.668102  193.681736  47580.99160     7.166639  359.948574
# 3272  7.808856  193.553212  17329.80216     8.061362  333.775777
# 3273  9.419510  175.762646  33155.57822     7.350233  333.775777
# 3274  5.126763  230.603758  11983.86938     6.303357  333.775777
# 3275  7.874671  195.102299  17404.17706     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       564.308654       10.379783        86.990970   2.963135
# 1       592.885359       15.180013        56.329076   4.500656
# 2       418.606213       16.868637        66.420093   3.055934
# 3       363.266516       18.436525       100.341674   4.628771
# 4       398.410813       11.558279        31.997993   4.075075
# ...            ...             ...              ...        ...
# 3271    526.424171       13.894419        66.687695   4.435821
# 3272    392.449580       19.903225        66.396293   2.798243
# 3273    432.044783       11.039070        69.845400   3.298875
# 3274    402.883113       11.168946        77.488213   4.708658
# 3275    327.459761       16.140368        78.698446   2.309149
#
# [3276 rows x 9 columns]
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3271    1
# 3272    1
# 3273    1
# 3274    1
# 3275    1
# Name: Potability, Length: 3276, dtype: int64

# %%
# Split the data into training (70%), validation (15%), and testing (15%)

from sklearn.model_selection import train_test_split

x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_val_scaled = scaler.transform(x_val)
X_test_scaled = scaler.transform(x_test)

# %% [markdown]
# # Each Member Defines their model Here

# %%
#Model Definition by member 2
from tensorflow.keras.optimizers import SGD # Import SGD

def shema_ivan():
  model = Sequential([
      Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)), # Use X_train_scaled
      Dropout(0.5),
      Dense(64, activation='relu'),
      Dropout(0.5),
      Dense(1, activation='sigmoid')
      ])
  return model

model = shema_ivan()

optimizer = SGD(learning_rate=0.05, momentum=0.9)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Start the training Process

# %%
# Train the model
history = model.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    epochs=50,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, classification_report

y_pred = (model.predict(X_test_scaled, verbose=0) > 0.5).astype(int)
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)

# Print results
print(f"\nResults:")
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Recall: {recall:.4f}")
print(f"Precision: {precision:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['Not Potable', 'Potable']))
# Out:
# Epoch 1/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5660 - loss: 0.7142 - val_accuracy: 0.6314 - val_loss: 0.6503
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6121 - loss: 0.6656 - val_accuracy: 0.6599 - val_loss: 0.6361
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6047 - loss: 0.6652 - val_accuracy: 0.6762 - val_loss: 0.6342
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6127 - loss: 0.6557 - val_accuracy: 0.6680 - val_loss: 0.6143
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6381 - loss: 0.6505 - val_accuracy: 0.6782 - val_loss: 0.6072
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6339 - loss: 0.6483 - val_accuracy: 0.6823 - val_loss: 0.6170
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6724 - loss: 0.6253 - val_accuracy: 0.6619 - val_loss: 0.6193
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6575 - loss: 0.6255 - val_accuracy: 0.6782 - val_loss: 0.6133
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6609 - loss: 0.6385 - val_accuracy: 0.6823 - val_loss: 0.6033
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6532 - loss: 0.6250 - val_accuracy: 0.6823 - val_loss: 0.6054
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6640 - loss: 0.6356 - val_accuracy: 0.6762 - val_loss: 0.6093
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6471 - loss: 0.6379 - val_accuracy: 0.6762 - val_loss: 0.6003
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6694 - loss: 0.6237 - val_accuracy: 0.6904 - val_loss: 0.5992
# Epoch 14/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6600 - loss: 0.6274 - val_accuracy: 0.6721 - val_loss: 0.6034
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6577 - loss: 0.6279 - val_accuracy: 0.6823 - val_loss: 0.6094
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6806 - loss: 0.6161 - val_accuracy: 0.6762 - val_loss: 0.5972
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6620 - loss: 0.6139 - val_accuracy: 0.6843 - val_loss: 0.5980
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6711 - loss: 0.6196 - val_accuracy: 0.6782 - val_loss: 0.5970
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6749 - loss: 0.6068 - val_accuracy: 0.6802 - val_loss: 0.6119
# Epoch 20/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6756 - loss: 0.6127 - val_accuracy: 0.6904 - val_loss: 0.6056
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6720 - loss: 0.6096 - val_accuracy: 0.6904 - val_loss: 0.5935
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6828 - loss: 0.6122 - val_accuracy: 0.6864 - val_loss: 0.5976
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6790 - loss: 0.6023 - val_accuracy: 0.6843 - val_loss: 0.6029
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6730 - loss: 0.6130 - val_accuracy: 0.6965 - val_loss: 0.5973
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6605 - loss: 0.6202 - val_accuracy: 0.6680 - val_loss: 0.5998
# Epoch 26/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6673 - loss: 0.6095 - val_accuracy: 0.6762 - val_loss: 0.6032
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6610 - loss: 0.6240 - val_accuracy: 0.6741 - val_loss: 0.5971
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6650 - loss: 0.6160 - val_accuracy: 0.6802 - val_loss: 0.5989
# Epoch 29/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6520 - loss: 0.6132 - val_accuracy: 0.6701 - val_loss: 0.6047
# Epoch 30/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6805 - loss: 0.6020 - val_accuracy: 0.6904 - val_loss: 0.6003
# Epoch 31/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6693 - loss: 0.6093 - val_accuracy: 0.6843 - val_loss: 0.6070
#
# Results:
# Accuracy: 0.6850
# F1 Score: 0.3775
# Recall: 0.2541
# Precision: 0.7344
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Not Potable       0.68      0.94      0.79       307
#      Potable       0.73      0.25      0.38       185
#
#     accuracy                           0.68       492
#    macro avg       0.71      0.60      0.58       492
# weighted avg       0.70      0.68      0.63       492

# %%
#Confusion Matrix
y_pred = (model.predict(X_test_scaled) > 0.5).astype(int)

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Potable', 'Potable'], yticklabels=['Not Potable', 'Potable'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
#Loss Curves
# Plot loss and accuracy curves
plt.figure(figsize=(12, 5))

# Loss curve
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy curve
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
