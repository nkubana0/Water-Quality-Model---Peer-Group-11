# %% [markdown]
# # Excercise - Creating our own custom Model

# %% [markdown]
# This is a notebook that provides a quick overview of how to create your own custom model. You will be creating a simple model.
# You will be utilizing Keras and Tensorflow

# %% [markdown]
# ## Water Quality Dataset
#
# This dataset contains water quality measurements and assessments related to potability, which is the suitability of water for human consumption. The dataset's primary objective is to provide insights into water quality parameters and assist in determining whether the water is potable or not. Each row in the dataset represents a water sample with specific attributes, and the "Potability" column indicates whether the water is suitable for consumption.
#
# https://www.kaggle.com/datasets/uom190346a/water-quality-and-potability?select=water_potability.csv

# %%
#mount the Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#LOAD THE DATA
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy
import pandas as pd
import numpy as np

dataset = pd.read_csv('/content/drive/My Drive/water_potability.csv')

# Check for missing values
print("Missing values per column:")
print(dataset.isnull().sum())

# Impute missing values with the mean for ph, Sulfate, and Trihalomethanes
dataset['ph'].fillna(dataset['ph'].mean(), inplace=True)
dataset['Sulfate'].fillna(dataset['Sulfate'].mean(), inplace=True)
dataset['Trihalomethanes'].fillna(dataset['Trihalomethanes'].mean(), inplace=True)

# Check for missing values
print("Missing values per column:")
print(dataset.isnull().sum())
# Out:
# Missing values per column:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64
# Missing values per column:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64
# <ipython-input-24-605ac43473b5>:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['ph'].fillna(dataset['ph'].mean(), inplace=True)
# <ipython-input-24-605ac43473b5>:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Sulfate'].fillna(dataset['Sulfate'].mean(), inplace=True)
# <ipython-input-24-605ac43473b5>:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Trihalomethanes'].fillna(dataset['Trihalomethanes'].mean(), inplace=True)

# %% [markdown]
# Plot the Data Appropriately

# %%
# generate 2d classification dataset
x = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

print(x)
print(y)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       564.308654       10.379783        86.990970   2.963135
# 1       592.885359       15.180013        56.329076   4.500656
# 2       418.606213       16.868637        66.420093   3.055934
# 3       363.266516       18.436524       100.341674   4.628771
# 4       398.410813       11.558279        31.997993   4.075075
# ...            ...             ...              ...        ...
# 3271    526.424171       13.894419        66.687695   4.435821
# 3272    392.449580       19.903225        66.396293   2.798243
# 3273    432.044783       11.039070        69.845400   3.298875
# 3274    402.883113       11.168946        77.488213   4.708658
# 3275    327.459760       16.140368        78.698446   2.309149
#
# [3276 rows x 9 columns]
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3271    1
# 3272    1
# 3273    1
# 3274    1
# 3275    1
# Name: Potability, Length: 3276, dtype: int64

# %%
# Split the data into training (70%), validation (15%), and testing (15%)

from sklearn.model_selection import train_test_split

x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_val_scaled = scaler.transform(x_val)
X_test_scaled = scaler.transform(x_test)

# %% [markdown]
# # Each Member Defines their model Here

# %%
def model_name_of_student_owen():

    model = Sequential([
        Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)),  # Input layer + first hidden layer
        Dropout(0.3),  # Dropout to prevent overfitting
        Dense(32, activation='relu'),  # Second hidden layer
        Dropout(0.3),
        Dense(16, activation='relu'),  # Third hidden layer
        Dense(1, activation='sigmoid')  # Output layer for binary classification
    ])

    #optimizer
    optimizer = tf.keras.optimizers.Adagrad(learning_rate=0.001)

    # Compile the model
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
#Model Definition by member 2
from tensorflow.keras.optimizers import SGD # Import SGD

def shema_ivan():
  model = Sequential([
      Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)), # Use X_train_scaled
      Dropout(0.5),
      Dense(64, activation='relu'),
      Dropout(0.5),
      Dense(1, activation='sigmoid')
      ])
  return model

model = shema_ivan()

optimizer = SGD(learning_rate=0.01, momentum=0.9)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#Model Definition by member 3
def model_name_of_student():

  return

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %% [markdown]
# # Start the training Process

# %%
# Train the model
history = model.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    epochs=50,
    batch_size=32,
    verbose=1
)

# Evaluate the model on the test set
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, classification_report

y_pred = (model.predict(X_test_scaled, verbose=0) > 0.5).astype(int)
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)

# Print results
print(f"\nResults:")
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Recall: {recall:.4f}")
print(f"Precision: {precision:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['Not Potable', 'Potable']))
# Out:
# Epoch 1/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5166 - loss: 0.7463 - val_accuracy: 0.6314 - val_loss: 0.6578
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5894 - loss: 0.6849 - val_accuracy: 0.6314 - val_loss: 0.6545
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6037 - loss: 0.6760 - val_accuracy: 0.6354 - val_loss: 0.6520
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5971 - loss: 0.6736 - val_accuracy: 0.6334 - val_loss: 0.6491
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6265 - loss: 0.6539 - val_accuracy: 0.6517 - val_loss: 0.6470
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6292 - loss: 0.6628 - val_accuracy: 0.6375 - val_loss: 0.6405
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6342 - loss: 0.6463 - val_accuracy: 0.6517 - val_loss: 0.6347
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6104 - loss: 0.6610 - val_accuracy: 0.6497 - val_loss: 0.6293
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6235 - loss: 0.6509 - val_accuracy: 0.6619 - val_loss: 0.6252
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6196 - loss: 0.6522 - val_accuracy: 0.6660 - val_loss: 0.6212
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6376 - loss: 0.6484 - val_accuracy: 0.6782 - val_loss: 0.6169
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6440 - loss: 0.6448 - val_accuracy: 0.6721 - val_loss: 0.6148
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6448 - loss: 0.6351 - val_accuracy: 0.6782 - val_loss: 0.6101
# Epoch 14/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6541 - loss: 0.6359 - val_accuracy: 0.6843 - val_loss: 0.6065
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6501 - loss: 0.6338 - val_accuracy: 0.6782 - val_loss: 0.6022
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6485 - loss: 0.6282 - val_accuracy: 0.6843 - val_loss: 0.6062
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6737 - loss: 0.6251 - val_accuracy: 0.6843 - val_loss: 0.6035
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6418 - loss: 0.6367 - val_accuracy: 0.6843 - val_loss: 0.6023
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6413 - loss: 0.6292 - val_accuracy: 0.6864 - val_loss: 0.6010
# Epoch 20/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6643 - loss: 0.6301 - val_accuracy: 0.6884 - val_loss: 0.5997
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6511 - loss: 0.6269 - val_accuracy: 0.6904 - val_loss: 0.5984
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6494 - loss: 0.6354 - val_accuracy: 0.6843 - val_loss: 0.6021
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6672 - loss: 0.6210 - val_accuracy: 0.6802 - val_loss: 0.5971
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6695 - loss: 0.6174 - val_accuracy: 0.6782 - val_loss: 0.5969
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6498 - loss: 0.6389 - val_accuracy: 0.6802 - val_loss: 0.5979
# Epoch 26/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6540 - loss: 0.6247 - val_accuracy: 0.6904 - val_loss: 0.5980
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6665 - loss: 0.6090 - val_accuracy: 0.6762 - val_loss: 0.5977
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6652 - loss: 0.6199 - val_accuracy: 0.6884 - val_loss: 0.5999
# Epoch 29/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6519 - loss: 0.6148 - val_accuracy: 0.6823 - val_loss: 0.5986
# Epoch 30/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6746 - loss: 0.6123 - val_accuracy: 0.6802 - val_loss: 0.5984
# Epoch 31/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6711 - loss: 0.6097 - val_accuracy: 0.6945 - val_loss: 0.5960
# Epoch 32/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6638 - loss: 0.6138 - val_accuracy: 0.6904 - val_loss: 0.5948
# Epoch 33/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6559 - loss: 0.6268 - val_accuracy: 0.6823 - val_loss: 0.5957
# Epoch 34/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6648 - loss: 0.6179 - val_accuracy: 0.6864 - val_loss: 0.5958
# Epoch 35/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6802 - loss: 0.6119 - val_accuracy: 0.6843 - val_loss: 0.5940
# Epoch 36/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7021 - loss: 0.5967 - val_accuracy: 0.6864 - val_loss: 0.5913
# Epoch 37/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6672 - loss: 0.6109 - val_accuracy: 0.6802 - val_loss: 0.5922
# Epoch 38/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6700 - loss: 0.6095 - val_accuracy: 0.6782 - val_loss: 0.5950
# Epoch 39/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6765 - loss: 0.6025 - val_accuracy: 0.6762 - val_loss: 0.5907
# Epoch 40/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6746 - loss: 0.6067 - val_accuracy: 0.6762 - val_loss: 0.5915
# Epoch 41/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6849 - loss: 0.6089 - val_accuracy: 0.6741 - val_loss: 0.5946
# Epoch 42/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6694 - loss: 0.6125 - val_accuracy: 0.6741 - val_loss: 0.5940
# Epoch 43/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6699 - loss: 0.6143 - val_accuracy: 0.6782 - val_loss: 0.5959
# Epoch 44/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6574 - loss: 0.6201 - val_accuracy: 0.6721 - val_loss: 0.5916
# Epoch 45/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6625 - loss: 0.6147 - val_accuracy: 0.6802 - val_loss: 0.5896
# Epoch 46/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6736 - loss: 0.6029 - val_accuracy: 0.6864 - val_loss: 0.5877
# Epoch 47/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6677 - loss: 0.6114 - val_accuracy: 0.6884 - val_loss: 0.5899
# Epoch 48/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6583 - loss: 0.6201 - val_accuracy: 0.6701 - val_loss: 0.5919
# Epoch 49/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6788 - loss: 0.6165 - val_accuracy: 0.6741 - val_loss: 0.5918
# Epoch 50/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6792 - loss: 0.6035 - val_accuracy: 0.6823 - val_loss: 0.5932
#
# Results:
# Accuracy: 0.6951
# F1 Score: 0.4094
# Recall: 0.2811
# Precision: 0.7536
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Not Potable       0.69      0.94      0.79       307
#      Potable       0.75      0.28      0.41       185
#
#     accuracy                           0.70       492
#    macro avg       0.72      0.61      0.60       492
# weighted avg       0.71      0.70      0.65       492

# %%
#Confusion Matrix
y_pred = (model.predict(X_test_scaled) > 0.5).astype(int)

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Potable', 'Potable'], yticklabels=['Not Potable', 'Potable'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
#Loss Curves
# Plot loss and accuracy curves
plt.figure(figsize=(12, 5))

# Loss curve
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy curve
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
